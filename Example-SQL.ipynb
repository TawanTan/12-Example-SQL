# %%
import pandas
import pymysql

# %% [markdown]
# เรียกใช้ ipython-sql

# %%
# %load_ext sql

# %% [markdown]
# # MySQL connection

# %%
import getpass
host = '127.0.0.1'
port = 3306
dbname = 'employees'

user = input('user name')
pwd = getpass.getpass('password')
# Out:
# user nameroot
# password········

# %%
connection_string=f'mysql+pymysql://{user}:{pwd}@{host}:{port}/{dbname}'

# %%
# %sql $connection_string

# %% [markdown]
# Example 2.1
# 1.เรียกดู column ของ dept_no จากตาราง departments

# %%
# %%sql
# select dept_no
# from departments
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 9 rows affected.
# [('d009',),
#  ('d005',),
#  ('d002',),
#  ('d003',),
#  ('d001',),
#  ('d004',),
#  ('d006',),
#  ('d008',),
#  ('d007',)]

# %% [markdown]
# 2.เรียกดูข้อมูลทั้งหมดจากตาราง departments

# %%
# %%sql
# select *
# from departments
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 9 rows affected.
# [('d009', 'Customer Service'),
#  ('d005', 'Development'),
#  ('d002', 'Finance'),
#  ('d003', 'Human Resources'),
#  ('d001', 'Marketing'),
#  ('d004', 'Production'),
#  ('d006', 'Quality Management'),
#  ('d008', 'Research'),
#  ('d007', 'Sales')]

# %% [markdown]
# Example 2.2
# 1.เรียกดูข้อมูลทั้งหมดจากตาราง employees ที่มี firstname คือ Elvis

# %%
# %%sql
# select *
# from employees
# where first_name = 'Elvis'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10030, datetime.date(1958, 7, 14), 'Elvis', 'Demeyer', 'M', datetime.date(1994, 2, 17)),
#  (11050, datetime.date(1952, 9, 23), 'Elvis', 'Katiyar', 'M', datetime.date(1986, 5, 6)),
#  (12870, datetime.date(1960, 3, 24), 'Elvis', 'Pfau', 'F', datetime.date(1990, 4, 9)),
#  (13620, datetime.date(1956, 10, 31), 'Elvis', 'Dolinsky', 'M', datetime.date(1985, 6, 12)),
#  (14434, datetime.date(1954, 7, 8), 'Elvis', 'Maginnis', 'M', datetime.date(1987, 11, 27))]

# %% [markdown]
# Example 2.3
# 1.เรียกดูข้อมูลทั้งหมดของ female ที่มี firstname เป็น Kellie จากตาราง employees

# %%
# %%sql
# select *
# from employees
# where first_name = 'Kellie' and gender = 'F'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10225, datetime.date(1957, 2, 13), 'Kellie', 'Chinen', 'F', datetime.date(1986, 6, 19)),
#  (14918, datetime.date(1962, 10, 16), 'Kellie', 'Kaiserswerth', 'F', datetime.date(1986, 11, 18)),
#  (22164, datetime.date(1957, 4, 5), 'Kellie', 'Argence', 'F', datetime.date(1989, 9, 9)),
#  (22335, datetime.date(1962, 4, 7), 'Kellie', 'Brandsma', 'F', datetime.date(1987, 11, 10)),
#  (30308, datetime.date(1961, 10, 1), 'Kellie', 'Riexinger', 'F', datetime.date(1992, 4, 17))]

# %% [markdown]
# Example 2.3
# 1.เรียกดูข้อมูลทั้งหมดของ firstname ที่เป็น Kellie หรือ Aruna จากตาราง employees

# %%
# %%sql
# select *
# from employees
# where first_name = 'Kellie' or first_name = 'Aruna'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10225, datetime.date(1957, 2, 13), 'Kellie', 'Chinen', 'F', datetime.date(1986, 6, 19)),
#  (10789, datetime.date(1964, 5, 19), 'Aruna', 'Journel', 'F', datetime.date(1987, 2, 2)),
#  (11217, datetime.date(1954, 7, 1), 'Kellie', 'Mawatari', 'M', datetime.date(1987, 9, 22)),
#  (11938, datetime.date(1954, 1, 14), 'Aruna', 'Verspoor', 'M', datetime.date(1994, 7, 15)),
#  (12038, datetime.date(1956, 4, 13), 'Aruna', 'Businaro', 'F', datetime.date(1987, 1, 9))]

# %% [markdown]
# Example 2.3( AND , OR )
# 1.เรียกดูข้อมูลทั้งหมดของ female ที่มี firstname ที่เป็น Kellie หรือ Aruna จากตาราง employees

# %%
# %%sql
# select *
# from employees
# where (first_name = 'Kellie' or first_name = 'Aruna') and gender = 'F'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10225, datetime.date(1957, 2, 13), 'Kellie', 'Chinen', 'F', datetime.date(1986, 6, 19)),
#  (10789, datetime.date(1964, 5, 19), 'Aruna', 'Journel', 'F', datetime.date(1987, 2, 2)),
#  (12038, datetime.date(1956, 4, 13), 'Aruna', 'Businaro', 'F', datetime.date(1987, 1, 9)),
#  (14080, datetime.date(1957, 2, 24), 'Aruna', 'Motley', 'F', datetime.date(1987, 3, 9)),
#  (14459, datetime.date(1964, 9, 21), 'Aruna', 'Boreale', 'F', datetime.date(1986, 12, 6))]

# %% [markdown]
# Example 2.4
# 1.เรียกดูข้อมูลทั้งหมดของ firstname ที่เป็น Denis หรือ Elvis จากตาราง employees

# %%
# %%sql
# select *
# from employees
# where first_name in ('Elvis', 'Denis')
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10030, datetime.date(1958, 7, 14), 'Elvis', 'Demeyer', 'M', datetime.date(1994, 2, 17)),
#  (11050, datetime.date(1952, 9, 23), 'Elvis', 'Katiyar', 'M', datetime.date(1986, 5, 6)),
#  (11688, datetime.date(1958, 9, 4), 'Denis', 'Coullard', 'F', datetime.date(1994, 10, 29)),
#  (12870, datetime.date(1960, 3, 24), 'Elvis', 'Pfau', 'F', datetime.date(1990, 4, 9)),
#  (13620, datetime.date(1956, 10, 31), 'Elvis', 'Dolinsky', 'M', datetime.date(1985, 6, 12))]

# %% [markdown]
# Example 2.4
# 1.เรียกดูข้อมูลทั้งหมดของ firstname ที่ไม่เป็น John , Mark หรือ Jacob จากตาราง employees

# %%
# %%sql
# select *
# from employees
# where first_name not in ('John', 'Mark', 'Jacob')
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26)),
#  (10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28)),
#  (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick', 'M', datetime.date(1986, 12, 1)),
#  (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak', 'M', datetime.date(1989, 9, 12))]

# %% [markdown]
# Example 2.5
# 1. เรียกดูข้อมูลทั้งหมดของ firstname ที่ขึ้นต้นด้วย Mark จากตาราง employees

# %%
# %%sql
# select *
# from employees
# where first_name like 'Mark%'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10232, datetime.date(1956, 3, 11), 'Marko', 'Auria', 'F', datetime.date(1992, 6, 4)),
#  (10415, datetime.date(1957, 11, 12), 'Mark', 'Coorg', 'M', datetime.date(1993, 10, 25)),
#  (10522, datetime.date(1955, 7, 24), 'Marke', 'Cesareni', 'F', datetime.date(1986, 12, 12)),
#  (11887, datetime.date(1957, 5, 25), 'Marke', 'Kragelund', 'M', datetime.date(1994, 10, 17)),
#  (12007, datetime.date(1952, 6, 18), 'Marko', 'Dehkordi', 'M', datetime.date(1989, 5, 17))]

# %% [markdown]
# 2. เรียกดูข้อมูลทั้งหมดของพนักงานที่มีหมายเลข 5 ตัวอักษรเป็นต้นไป เริ่มที่ 1000_ จากตาราง employees

# %%
# %%sql
# select *
# from employees
# where emp_no like '1000_'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26)),
#  (10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21)),
#  (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28)),
#  (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick', 'M', datetime.date(1986, 12, 1)),
#  (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak', 'M', datetime.date(1989, 9, 12))]

# %% [markdown]
# Example 2.6
# 1. เรียกดูข้อมูลทั้งหมดของสัญญาค่าจ้างระหว่าง 66,000 จนถึง 70,000 ดอลลาร์ต่อปี จากตาราง salaries

# %%
# %%sql
# select *
# from salaries
# where salary between 66000 and 70000
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10001, 66074, datetime.date(1988, 6, 25), datetime.date(1989, 6, 25)),
#  (10001, 66596, datetime.date(1989, 6, 25), datetime.date(1990, 6, 25)),
#  (10001, 66961, datetime.date(1990, 6, 25), datetime.date(1991, 6, 25)),
#  (10002, 67534, datetime.date(1998, 8, 3), datetime.date(1999, 8, 3)),
#  (10002, 69366, datetime.date(1999, 8, 3), datetime.date(2000, 8, 2))]

# %% [markdown]
# 2.  เรียกดูข้อมูลทั้งหมดของพนักงานที่มีหมายเลขไม่ได้อยู่ระหว่าง 10004 จนถึง 10012 จากตาราง employees

# %%
# %%sql
# select *
# from salaries
# where emp_no not  between 10004 and 10012
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10001, 60117, datetime.date(1986, 6, 26), datetime.date(1987, 6, 26)),
#  (10001, 62102, datetime.date(1987, 6, 26), datetime.date(1988, 6, 25)),
#  (10001, 66074, datetime.date(1988, 6, 25), datetime.date(1989, 6, 25)),
#  (10001, 66596, datetime.date(1989, 6, 25), datetime.date(1990, 6, 25)),
#  (10001, 66961, datetime.date(1990, 6, 25), datetime.date(1991, 6, 25))]

# %% [markdown]
# 3. เรียกดูข้อมูลทั้งหมดชื่อของ department ที่มีหมายเลขอยู่ระหว่าง d003 จนถึง d006 จากตาราง  department

# %%
# %%sql
# select *
# from departments
# where dept_no between 'd003' and 'd006'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 4 rows affected.
# [('d005', 'Development'),
#  ('d003', 'Human Resources'),
#  ('d004', 'Production'),
#  ('d006', 'Quality Management')]

# %% [markdown]
# Example 2.7
# 1. เรียกดูข้อมูลทั้งหมดชื่อของ department จากตาราง  departments ที่ไม่มีข้อมูลว่าง

# %%
# %%sql
# select dept_name
# from departments
# where dept_no is not null
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [('Customer Service',),
#  ('Development',),
#  ('Finance',),
#  ('Human Resources',),
#  ('Marketing',)]

# %% [markdown]
# Example 2.8
# 1. เรียกดูข้อมูลทั้งหมดของพนักงานผู้หญิงที่ถูกจ้างตั้งแต่ปี 2000 เป็นต้นไป

# %%
# %%sql
# select *
# from employees
# where hire_date >= '2000-01-01'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(47291, datetime.date(1960, 9, 9), 'Ulf', 'Flexer', 'M', datetime.date(2000, 1, 12)),
#  (60134, datetime.date(1964, 4, 21), 'Seshu', 'Rathonyi', 'F', datetime.date(2000, 1, 2)),
#  (72329, datetime.date(1953, 2, 9), 'Randi', 'Luit', 'F', datetime.date(2000, 1, 2)),
#  (108201, datetime.date(1955, 4, 14), 'Mariangiola', 'Boreale', 'M', datetime.date(2000, 1, 1)),
#  (205048, datetime.date(1960, 9, 12), 'Ennio', 'Alblas', 'F', datetime.date(2000, 1, 6))]

# %% [markdown]
# 2. เรียกดูข้อมูลทั้งหมดของพนักงานทุกคนที่มีรายได้สูงกว่า 150,000 ดอลลาร์ต่อปี

# %%
# %%sql
# select *
# from salaries
# where salary > 150000
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 0 rows affected.
# []

# %% [markdown]
# Example 2.9
# 1. เรียกดูข้อมูลทั้งหมดของวันที่จ้างงานที่แตกต่างกันจากตาราง employees

# %%
# %%sql
# select distinct hire_date
# from employees
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(datetime.date(1986, 6, 26),),
#  (datetime.date(1985, 11, 21),),
#  (datetime.date(1986, 8, 28),),
#  (datetime.date(1986, 12, 1),),
#  (datetime.date(1989, 9, 12),)]

# %% [markdown]
# Example 2.10
# 1. เรียกดูข้อมูลทั้งหมดของสัญญาจ้างที่มีมูลค่าสูงกว่า 100,000 ดอลลาร์ต่อปี ขึ้นไปจากตาราง salaries

# %%
# %%sql
# select count(*)
# from salaries
# where salary >= 100000
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(9448,)]

# %% [markdown]
# 2. เรียกดูข้อมูลทั้งหมดของ managers ที่มีอยู่จากตาราง dept_manager

# %%
# %%sql
# select count(*)
# from dept_manager
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(24,)]

# %% [markdown]
# Example 2.11
# 1. เรียกดูข้อมูลทั้งหมดของวันที่จ้างทำงานตั้งแต่ปัจจุบันไปยังอดีตที่มีอยู่จากตาราง employees

# %%
# %%sql
# select *
# from employees
# order by hire_date desc
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(463807, datetime.date(1964, 6, 12), 'Bikash', 'Covnot', 'M', datetime.date(2000, 1, 28)),
#  (428377, datetime.date(1957, 5, 9), 'Yucai', 'Gerlach', 'M', datetime.date(2000, 1, 23)),
#  (499553, datetime.date(1954, 5, 6), 'Hideyuki', 'Delgrande', 'F', datetime.date(2000, 1, 22)),
#  (222965, datetime.date(1959, 8, 7), 'Volkmar', 'Perko', 'F', datetime.date(2000, 1, 13)),
#  (47291, datetime.date(1960, 9, 9), 'Ulf', 'Flexer', 'M', datetime.date(2000, 1, 12))]

# %% [markdown]
# Example 2.12
# 1. เรียกดูข้อมูลทั้งหมดของคอลัมน์แรกจะต้องมีเงินเดือนต่อปีสูงกว่า 80,000 ดอลลาร์ ในส่วนคอลัมน์ที่สองเปลี่ยนชื่อเป็น“ emps_with_same_salary” ต้องแสดงจำนวนสัญญาว่าจ้างของพนักงานในตาราง salary

# %%
# %%sql
# select salary, count(emp_no) as emps_with_same_salary
# from salaries
# where salary > 80000
# group by salary
# order by salary
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(80001, 4), (80002, 3), (80003, 2), (80004, 2), (80005, 3)]

# %% [markdown]
# Example 2.13
# 1. เรียกดูข้อมูลทั้งหมดของค่าเฉลี่ยเงินพนักงานที่สูงกว่า 120,000 ดอลลาร์ต่อปี

# %%
# %%sql
# select  emp_no, avg (salary) as AVGS
# from salaries
# group by emp_no
# having AVGS > 120000
# order by emp_no
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(11486, Decimal('124462.1111')),
#  (12149, Decimal('123656.9286')),
#  (13555, Decimal('120264.2143')),
#  (14487, Decimal('125684.8750')),
#  (14508, Decimal('120655.1111'))]

# %% [markdown]
# Example 2.13
# 1. เรียกดูข้อมูลหมายเลขพนักงานทุกคนที่ลงนามมากกว่า 1 สัญญาหลังจากวันที่ 1 มกราคม 2000

# %%
# %%sql
# select emp_no, count(from_date)
# from dept_emp
# where from_date > '2000-01-01'
# group by emp_no
# having count(from_date) > 1
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(11609, 2), (13626, 2), (15893, 2), (16689, 2), (19964, 2)]

# %% [markdown]
# Example 2.14
# 1. เรียกดูข้อมูล 100 บรรทัดแรกจากตาราง dept_emp

# %%
# %sql select * from dept_emp limit 100
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 100 rows affected.
# [(10001, 'd005', datetime.date(1986, 6, 26), datetime.date(9999, 1, 1)),
#  (10002, 'd007', datetime.date(1996, 8, 3), datetime.date(9999, 1, 1)),
#  (10003, 'd004', datetime.date(1995, 12, 3), datetime.date(9999, 1, 1)),
#  (10004, 'd004', datetime.date(1986, 12, 1), datetime.date(9999, 1, 1)),
#  (10005, 'd003', datetime.date(1989, 9, 12), datetime.date(9999, 1, 1)),
#  (10006, 'd005', datetime.date(1990, 8, 5), datetime.date(9999, 1, 1)),
#  (10007, 'd008', datetime.date(1989, 2, 10), datetime.date(9999, 1, 1)),
#  (10008, 'd005', datetime.date(1998, 3, 11), datetime.date(2000, 7, 31)),
#  (10009, 'd006', datetime.date(1985, 2, 18), datetime.date(9999, 1, 1)),
#  (10010, 'd004', datetime.date(1996, 11, 24), datetime.date(2000, 6, 26)),
#  (10010, 'd006', datetime.date(2000, 6, 26), datetime.date(9999, 1, 1)),
#  (10011, 'd009', datetime.date(1990, 1, 22), datetime.date(1996, 11, 9)),
# ...

# %% [markdown]
# Example 3.1
# 1. เรียกดูจำนวนข้อมูลทั้งหมดแผนกจากตาราง dept_emp

# %%
# %sql select count(distinct dept_no) from dept_emp
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(9,)]

# %% [markdown]
# Example 3.2
# 1. เรียกดูจำนวนเงินทั้งหมดที่ใช้ในการจ่ายเงินเดือนสำหรับทุกสัญญาจ้างเริ่มตั้งแต่วันที่ 1 มกราคม 1997

# %%
# %%sql
# select sum(salary)
# from salaries
# where from_date >= '1997-01-01'
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(Decimal('9284842233'),)]

# %% [markdown]
# Example 3.3
# 1. เรียกดูหมายเลขของพนักงานที่ต่ำสุด

# %%
# %%sql
# select min(emp_no)
# from employees
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(10001,)]

# %% [markdown]
# 2. เรียกดูหมายเลขของพนักงานที่สูงสุด

# %%
# %%sql
# select max(emp_no)
# from employees
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(499999,)]

# %% [markdown]
# Example 3.4
# 1. เรียกดูค่าเฉลี่ยเงินทั้งหมดที่ใช้ในการจ่ายเงินเดือนสำหรับทุกสัญญาจ้างเริ่มตั้งแต่วันที่ 1 มกราคม 1997

# %%
# %%sql
# select avg(salary)
# from salaries
# where from_date >= '1997-01-01'
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(Decimal('67746.8569'),)]

# %% [markdown]
# Example 3.5
# 1. เรียกดูค่าเฉลี่ยเงินทั้งหมดที่ใช้ในการจ่ายเงินเดือนสำหรับทุกสัญญาจ้างเริ่มตั้งแต่วันที่ 1 มกราคม 1997 ในหน่วยเซนต์ (cents)

# %%
# %%sql
# select round(avg(salary), 2)
# from salaries
# where from_date >= '1997-01-01'
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(Decimal('67746.86'),)]

# %% [markdown]
# Example 4.1
# สร้างและเติมข้อมูลลงไปในตาราง departments_dup

# %%
# %%sql
# DROP TABLE IF EXISTS departments_dup;
# CREATE TABLE departments_dup ( dept_no CHAR(4) NULL , dept_name VARCHAR(40) NULL);
# INSERT INTO departments_dup ( dept_no, dept_name ) SELECT * FROM departments;
# INSERT INTO departments_dup (dept_name) VALUES  ('Public Relations');
# DELETE FROM departments_dup WHERE dept_no = 'd002';
# INSERT INTO departments_dup(dept_no) VALUES ('d010'), ('d011');
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 0 rows affected.
# 0 rows affected.
# C:\Users\msi\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1051, "Unknown table 'employees.departments_dup'")
#   result = self._query(query)
# 9 rows affected.
# 1 rows affected.
# 1 rows affected.
# 2 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS dept_manager_dup;
# CREATE TABLE dept_manager_dup ( emp_no int(11) NOT NULL, dept_no char(4) NULL, from_date date NOT NULL, to_date date NULL );
# INSERT INTO dept_manager_dup select * from dept_manager;
#  INSERT INTO dept_manager_dup (emp_no, from_date) VALUES (999904, '2017-01-01'), (999905,'2017-01-01'),(999906, '2017-01-01'),(999907, '2017-01-01');
#  DELETE FROM dept_manager_dup WHERE dept_no = 'd001';
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 0 rows affected.
# 0 rows affected.
# 24 rows affected.
# 4 rows affected.
# 2 rows affected.
# C:\Users\msi\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1051, "Unknown table 'employees.dept_manager_dup'")
#   result = self._query(query)
# C:\Users\msi\anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1681, 'Integer display width is deprecated and will be removed in a future release.')
#   result = self._query(query)
# []

# %% [markdown]
# Example 4.1.3
# 1.เรียกดูข้อมูลหมายเลขพนักงาน,ชื่อ - นามสกุล, หมายเลขของแผนก และ วันที่ว่าจ้างของผู้จัดการโดยใช้ where และ join

# %%
# %%sql
# select em.emp_no, em.first_name, em.last_name, dep.dept_no, em.hire_date
# from employees em, dept_emp dep
# where em.emp_no = dep.emp_no
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(10001, 'Georgi', 'Facello', 'd005', datetime.date(1986, 6, 26)),
#  (10002, 'Bezalel', 'Simmel', 'd007', datetime.date(1985, 11, 21)),
#  (10003, 'Parto', 'Bamford', 'd004', datetime.date(1986, 8, 28)),
#  (10004, 'Chirstian', 'Koblick', 'd004', datetime.date(1986, 12, 1)),
#  (10005, 'Kyoichi', 'Maliniak', 'd003', datetime.date(1989, 9, 12))]

# %% [markdown]
# Example 4.1.4
# 1.เรียกดูเลือกชื่อและนามสกุล,วันที่ว่าจ้างและตำแหน่งงานของพนักงานทุกคนที่มีชื่อ "Margareta" และมีนามสกุล "Markovitch"โดยใช้ where และ join ร่วมกัน

# %%
# %%sql
# select em.first_name, em.last_name, em.hire_date, t.title
# from employees em join titles t on em.emp_no = t.emp_no
# where em.first_name = 'Margareta' and em.last_name = 'Markovitch'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 2 rows affected.
# [('Margareta', 'Markovitch', datetime.date(1985, 1, 1), 'Manager'),
#  ('Margareta', 'Markovitch', datetime.date(1985, 1, 1), 'Senior Staff')]

# %% [markdown]
# Example 4.2
# เรียกดูข้อมูลหมายเลขพนักงาน,ชื่อ - นามสกุล, หมายเลขของแผนก และ วันที่ว่าจ้างของผู้จัดการ

# %%
# %%sql
# select em.emp_no, em.first_name, em.last_name, depm.dept_no, em.hire_date
# from employees em join dept_manager depm on em.emp_no = depm.emp_no
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 5 rows affected.
# [(110022, 'Margareta', 'Markovitch', 'd001', datetime.date(1985, 1, 1)),
#  (110039, 'Vishwani', 'Minakawa', 'd001', datetime.date(1986, 4, 12)),
#  (110085, 'Ebru', 'Alpin', 'd002', datetime.date(1985, 1, 1)),
#  (110114, 'Isamu', 'Legleitner', 'd002', datetime.date(1985, 1, 14)),
#  (110183, 'Shirish', 'Ossenbruggen', 'd003', datetime.date(1985, 1, 1))]

# %% [markdown]
# Example 4.3
# เชื่อมตาราง 'employees' และ 'dept_manager' เพื่อเรียกดูพนักงานที่เป็นผู้จัดการทุกคนที่มีนามสกุล Markovitch

# %%
# %%sql
# select em.emp_no, em.first_name, em.last_name
# from dept_manager depm left join employees em on em.emp_no = depm.emp_no
# where em.last_name = 'Markovitch'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(110022, 'Margareta', 'Markovitch')]

# %% [markdown]
# Example 4.4
# เชื่อมตาราง 'employees' และ 'dept_manager' เพื่อเรียกดูพนักงานที่เป็นผู้จัดการทุกคนที่มีนามสกุล Markovitch

# %%
# %%sql
# select em.emp_no, em.first_name, em.last_name
# from employees em right join  dept_manager depm on em.emp_no = depm.emp_no
# where em.last_name = 'Markovitch'
# limit 5
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 1 rows affected.
# [(110022, 'Margareta', 'Markovitch')]

# %% [markdown]
# Example 4.5
# ใช้คำสั่ง cross join เพื่อเรียกดูความเกี่ยวข้องกันของผู้จัดการจากตาราง dept_manager และ department หมายเลข 9

# %%
# %%sql
# select depm.*, dep.*
# from dept_manager depm cross join departments dep
# where dep.dept_no = 'd009'
# order by depm.emp_no
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 24 rows affected.
# [(110022, 'd001', datetime.date(1985, 1, 1), datetime.date(1991, 10, 1), 'd009', 'Customer Service'),
#  (110039, 'd001', datetime.date(1991, 10, 1), datetime.date(9999, 1, 1), 'd009', 'Customer Service'),
#  (110085, 'd002', datetime.date(1985, 1, 1), datetime.date(1989, 12, 17), 'd009', 'Customer Service'),
#  (110114, 'd002', datetime.date(1989, 12, 17), datetime.date(9999, 1, 1), 'd009', 'Customer Service'),
#  (110183, 'd003', datetime.date(1985, 1, 1), datetime.date(1992, 3, 21), 'd009', 'Customer Service'),
#  (110228, 'd003', datetime.date(1992, 3, 21), datetime.date(9999, 1, 1), 'd009', 'Customer Service'),
#  (110303, 'd004', datetime.date(1985, 1, 1), datetime.date(1988, 9, 9), 'd009', 'Customer Service'),
#  (110344, 'd004', datetime.date(1988, 9, 9), datetime.date(1992, 8, 2), 'd009', 'Customer Service'),
# ...

# %% [markdown]
# 2.ใช้คำสั่ง where เพื่อเรียกดูพนักงาน 10 คนแรกจากทุกแผนก

# %%
# %%sql
# select em.*, dep.*
# from employees em cross join departments dep
# where em.emp_no < 10011
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 90 rows affected.
# [(10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26), 'd009', 'Customer Service'),
#  (10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26), 'd005', 'Development'),
#  (10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26), 'd002', 'Finance'),
#  (10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26), 'd003', 'Human Resources'),
#  (10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26), 'd001', 'Marketing'),
#  (10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26), 'd004', 'Production'),
#  (10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26), 'd006', 'Quality Management'),
# ...

# %% [markdown]
# Example 4.6
# ความหมายของเครื่องหมายลบซับเซตของ a ที่บรรทัดสุดท้าย
# (ORDER BY -a.emp_no DESC)

# %%
# %%sql
# SELECT *
# FROM (SELECT e.emp_no, e.first_name, e.last_name, NULL AS dept_no, NULL AS from_date FROM employees e
# WHERE last_name = 'Denis'
# UNION SELECT NULL AS emp_no, NULL AS first_name, NULL AS  last_name, dm.dept_no,dm.from_date
# FROM dept_manager dm) as a ORDER BY -a.emp_no DESC;
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 189 rows affected.
# [(13009, 'Marc', 'Denis', None, None),
#  (13072, 'Jaques', 'Denis', None, None),
#  (13300, 'Mountaz', 'Denis', None, None),
#  (13984, 'Yongmao', 'Denis', None, None),
#  (14168, 'Jiann', 'Denis', None, None),
#  (15401, 'Limsoon', 'Denis', None, None),
#  (15721, 'Perla', 'Denis', None, None),
#  (15990, 'Hitomi', 'Denis', None, None),
#  (16353, 'Shawna', 'Denis', None, None),
#  (18907, 'Radhia', 'Denis', None, None),
#  (19109, 'Jenwei', 'Denis', None, None),
#  (19550, 'Pranjal', 'Denis', None, None),
#  (19859, 'Gal', 'Denis', None, None),
#  (21222, 'Akemi', 'Denis', None, None),
#  (26480, 'Flemming', 'Denis', None, None),
#  (26750, 'Baziley', 'Denis', None, None),
#  (28956, 'Kristian', 'Denis', None, None),
#  (29212, 'Magy', 'Denis', None, None),
#  (31678, 'Richara', 'Denis', None, None),
#  (33408, 'Shigeo', 'Denis', None, None),
#  (33983, 'Tesuya', 'Denis', None, None),
# ...

# %% [markdown]
# Example 5.1
# 1.เรียกดูผู้จัดการแผนกทั้งหมดที่ได้รับการว่าจ้างระหว่าง 1 มกราคม 2533 และ 1 มกราคม 2538

# %%
# %%sql
# select *
# from dept_manager
# where emp_no in (select emp_no
#        from employees
#        where hire_date between '1990-01-01' and '1995-01-01')
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/employees
# 2 rows affected.
# [(110420, 'd004', datetime.date(1996, 8, 30), datetime.date(9999, 1, 1)),
#  (111877, 'd009', datetime.date(1992, 9, 8), datetime.date(1996, 1, 3))]
